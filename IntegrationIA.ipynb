# %% [markdown]
# <a href="https://colab.research.google.com/github/Bachir-Bouhafs/EventsDelegateInCsharp/blob/master/IntegrationIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/antiplasti/Plastic-Detection-Model.git
# Out:
# Cloning into 'Plastic-Detection-Model'...
# remote: Enumerating objects: 115, done.
# remote: Total 115 (delta 0), reused 0 (delta 0), pack-reused 115
# Receiving objects: 100% (115/115), 42.76 MiB | 36.00 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# !unzip /content/training_dataset.zip
# Out:
# Archive:  /content/training_dataset.zip
#    creating: training_dataset/
#    creating: training_dataset/cardboard/
#   inflating: training_dataset/cardboard/cardboard1.jpg
#   inflating: training_dataset/cardboard/cardboard10.jpg
#   inflating: training_dataset/cardboard/cardboard100.jpg
#   inflating: training_dataset/cardboard/cardboard101.jpg
#   inflating: training_dataset/cardboard/cardboard102.jpg
#   inflating: training_dataset/cardboard/cardboard103.jpg
#   inflating: training_dataset/cardboard/cardboard104.jpg
#   inflating: training_dataset/cardboard/cardboard105.jpg
#   inflating: training_dataset/cardboard/cardboard106.jpg
#   inflating: training_dataset/cardboard/cardboard107.jpg
#   inflating: training_dataset/cardboard/cardboard108.jpg
#   inflating: training_dataset/cardboard/cardboard109.jpg
#   inflating: training_dataset/cardboard/cardboard11.jpg
#   inflating: training_dataset/cardboard/cardboard110.jpg
#   inflating: training_dataset/cardboard/cardboard111.jpg
# ...

# %%
# !bash /content/Plastic-Detection-Model/train.sh
# Out:
# 2020-07-13 08:00:10.240393: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# >> Downloading inception-2015-12-05.tgz 100.0%
# Successfully downloaded inception-2015-12-05.tgz 88931400 bytes.
# WARNING:tensorflow:From /content/Plastic-Detection-Model/retrain.py:263: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# W0713 08:00:15.815715 140001129396096 deprecation.py:323] From /content/Plastic-Detection-Model/retrain.py:263: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# 2020-07-13 08:00:16.454421: W tensorflow/core/framework/op_def_util.cc:371] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# ...

# %%
# !python /content/Plastic-Detection-Model/classify.py
# Out:
# 2020-07-13 08:16:57.690629: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1

# %%
# !python /content/Plastic-Detection-Model/testing.py
# Out:
# 2020-07-13 08:17:03.521934: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "/content/Plastic-Detection-Model/testing.py", line 6, in <module>
#     result = classify.analyse(imagePath)
#   File "/content/Plastic-Detection-Model/classify.py", line 12, in analyse
#     image_data = tf.io.gfile.GFile("/content/Plastic-Detection-Model/static/images/"+imageObj, 'rb').read()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/lib/io/file_io.py", line 116, in read
#     self._preread_check()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/lib/io/file_io.py", line 79, in _preread_check
#     self.__name, 1024 * 512)
# tensorflow.python.framework.errors_impl.NotFoundError: /content/Plastic-Detection-Model/static/images/testing.png; No such file or directory

# %%
# !git clone https://github.com/gxercavins/image-api.git
# Out:
# Cloning into 'image-api'...
# remote: Enumerating objects: 85, done.
# remote: Total 85 (delta 0), reused 0 (delta 0), pack-reused 85
# Unpacking objects: 100% (85/85), done.

# %%
# !pip install flask-ngrok
